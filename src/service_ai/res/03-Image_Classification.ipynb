# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
import cv2  # Install opencv-python
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("../artifacts/model/keras_Model.h5", compile=False)

# Load the labels
class_names = open("../artifacts/model/labels.txt", "r").readlines()

# CAMERA can be 0 or 1 based on default camera of your computer
camera = cv2.VideoCapture(0)

while True:
    # Grab the webcamera's image.
    ret, image = camera.read()

    # Resize the raw image into (224-height,224-width) pixels
    image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Show the image in a window
    cv2.imshow("Webcam Image", image)

    # Make the image a numpy array and reshape it to the models input shape.
    image = np.asarray(image, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize the image array
    image = (image / 127.5) - 1

    # Predicts the model
    prediction = model.predict(image)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Print prediction and confidence score
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", str(np.round(confidence_score * 100))[:-2], "%")

    # Listen to the keyboard for presses.
    keyboard_input = cv2.waitKey(1)

    # 27 is the ASCII for the esc key on your keyboard.
    if keyboard_input == 27:
        
        break
    

camera.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 4s 4s/step
# Class: No Food
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 134ms/step
# Class: No Food
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 115ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 126ms/step
# Class: No Food
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 136ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 119ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 138ms/step
# Class: No Food
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 122ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 132ms/step
# Class: No Food
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 116ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 134ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 144ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 144ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 146ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 117ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 136ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 115ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 136ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 138ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 137ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 132ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 186ms/step
# Class: No Food
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 155ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 117ms/step
# Class: No Food
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 175ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 158ms/step
# Class: No Food
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 157ms/step
# Class: No Food
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 146ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 121ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 121ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 141ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 158ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 147ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 143ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 170ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 296ms/step
# Class: No Food
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 191ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 143ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 173ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 182ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 143ms/step
# Class: No Food
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 145ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 147ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 129ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 147ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 168ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 116ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 151ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 141ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 148ms/step
# Class: No Food
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 167ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 157ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 138ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 126ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 126ms/step
# Class: No Food
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 129ms/step
# Class: No Food
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 118ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 132ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 138ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 145ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 157ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 120ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 137ms/step
# Class: No Food
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 137ms/step
# Class: No Food
# Confidence Score: 97 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 19
#      15 camera = cv2.VideoCapture(0)
#      17 while True:
#      18     # Grab the webcamera's image.
# ---> 19     ret, image = camera.read()
#      21     # Resize the raw image into (224-height,224-width) pixels
#      22     image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
